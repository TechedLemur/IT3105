# %%
# %load_ext autoreload
# %autoreload 2
# Enable interactive plot
# %matplotlib ipympl

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from simworld import SimWorld
import random

# %%
s = SimWorld()

# %%
# lines = np.zeros((300,2,3))
for i in range(300):
    # x = [0,s.state.xp2,s.state.x_tip]
    # y = [0,s.state.yp2,s.state.y_tip]
    s.do_action(random.randint(0,2))
    # s.do_action(0)
    # lines[i,0] = x 
    # lines[i,1] = y

x = s.x_history
y = s.y_history

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.set(xlim=(-2.5, 2.5), ylim=(-2.5, 2.5))

line = ax.plot(x[0], y[0], 'o-' , color='k', lw=2)[0]

def animate(i):
    line.set_xdata(x[i])
    line.set_ydata(y[i])
    # return line

# t = np.linspace(1, 25, 30)

anim = FuncAnimation(
    fig, animate, interval=50)#, frames=len(t)-1)

plt.draw()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
s.plot_current_state()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
